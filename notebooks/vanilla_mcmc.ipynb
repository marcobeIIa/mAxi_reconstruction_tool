# %% [markdown]
# # MCMC analysis notebook
# ## using the vanilla MontePython analysis tools
# (there si another notebook using getdist, getdist_mcmc.ipynb, which should be preferred. this notebook was used for simplicity, and is now legacy)

# %%
import subprocess
from pathlib import Path

bases = ["/Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/", "/Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_axions"]

chains = [
        "planck_TTTEEElensing_pantheon_plus_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_desi_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_boss_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_sh0es_boss_2025-12-19",
         ]

chains2 = [
        "planck_TTTEEElensing_2025-12-23",
        "planck_TTTEEElensing_pantheon_plus_2025-12-23",
        "planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-23",
        "planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-23",
         ]

for chain in chains:
    cmd = [
        "python",
        "/Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py",
        "info",
        str(Path(bases[0]) / chain)
    ]
    print("Running:", " ".join(cmd))
    subprocess.run(cmd, check=True)

for chain in chains2:
    cmd = [
        "python",
        "/Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py",
        "info",
        str(Path(bases[1]) / chain)
    ]
    print("Running:", " ".join(cmd))
    subprocess.run(cmd, check=True)
# Out:
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_2025-12-19
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_2025-12-19/2025-12-19_1000000__2.txt: Removed 0 non-markovian points, 92 points of burn-in, keep 1798 steps
#                                                                                                                                               2025-12-19_1000000__3.txt: Removed 0 non-markovian points, 8 points of burn-in, keep 1947 steps
#                                                                                                                                               2025-12-19_1000000__1.txt: Removed 0 non-markovian points, 122 points of burn-in, keep 1713 steps
#                                                                                                                                               2025-12-19_1000000__4.txt: Removed 0 non-markovian points, 134 points of burn-in, keep 1731 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.039679 	for  H0
#            0.100311 	for  omega_b
#            0.015571 	for  omega_cdm
#            0.005426 	for  ln10^{10}A_s
#            0.033850 	for  n_s
#            0.001439 	for  tau_reio
#            0.052789 	for  fraction_maxion_ac__1
#            0.003497 	for  fraction_maxion_ac__2
#            0.027928 	for  fraction_maxion_ac__3
#            0.027363 	for  fraction_maxion_ac__4
#            0.070836 	for  fraction_maxion_ac__5
#            0.015761 	for  fraction_maxion_ac__6
#            0.007701 	for  fraction_maxion_ac__7
#            0.020758 	for  fraction_maxion_ac__8
#            0.015454 	for  fraction_maxion_ac__9
#            0.004735 	for  A_planck
#            0.041776 	for  M
#            0.002587 	for  z_reio
#            0.036228 	for  Omega_Lambda
#            0.040586 	for  Omega_m
#            0.099624 	for  YHe
#            0.007356 	for  100*theta_s
#            0.007356 	for  A_s
#            0.013747 	for  sigma8
#            0.023655 	for  rs_d
#            0.023654 	for  a_eq
#            0.016161 	for  k_eq
#            0.016161 	for  rd_star
#            0.021851 	for  rs_star
#            0.021302 	for  da_star
#            0.011707 	for  z_star
#            0.022142 	for  rs_rec
#            0.021736 	for  da_rec
#            0.041442 	for  z_rec
#            0.030605 	for  age
#            0.016367 	for  theta_star_100
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  -> Computing histograms for  M
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  z_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_Lambda
#  -> Computing histograms for  Omega_m
#  -> Computing histograms for  YHe
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  100*theta_s
#  /!\ Polyfit may be poorly conditioned
#  -> Computing histograms for  A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  sigma8
#  -> Computing histograms for  rs_d
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  a_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  k_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rd_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_rec
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  age
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  theta_star_100
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-19
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-19/2025-12-19_1000000__2.txt: Removed 0 non-markovian points, 2 points of burn-in, keep 1008 steps
#                                                                                                                                                     2025-12-19_1000000__3.txt: Removed 0 non-markovian points, 76 points of burn-in, keep 1044 steps
#                                                                                                                                                     2025-12-19_1000000__1.txt: Removed 0 non-markovian points, 134 points of burn-in, keep 906 steps
#                                                                                                                                                     2025-12-19_1000000__4.txt: Removed 0 non-markovian points, 15 points of burn-in, keep 940 steps
#                                                                                                                                                     2025-12-26_2000000__4.txt: Removed 0 non-markovian points, 15 points of burn-in, keep 1435 steps
#                                                                                                                                                     2025-12-26_2000000__1.txt: Removed 0 non-markovian points, 134 points of burn-in, keep 1441 steps
#                                                                                                                                                     2025-12-26_2000000__3.txt: Removed 0 non-markovian points, 76 points of burn-in, keep 1539 steps
#                                                                                                                                                     2025-12-26_2000000__2.txt: Removed 0 non-markovian points, 2 points of burn-in, keep 1443 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.368854 	for  H0
#            0.010885 	for  omega_b
#            0.145348 	for  omega_cdm
#            0.059858 	for  ln10^{10}A_s
#            0.126797 	for  n_s
#            0.021536 	for  tau_reio
#            0.028199 	for  fraction_maxion_ac__1
#            0.001950 	for  fraction_maxion_ac__2
#            0.113438 	for  fraction_maxion_ac__3
#            0.038714 	for  fraction_maxion_ac__4
#            0.034443 	for  fraction_maxion_ac__5
#            0.026574 	for  fraction_maxion_ac__6
#            0.031305 	for  fraction_maxion_ac__7
#            0.043371 	for  fraction_maxion_ac__8
#            0.012709 	for  fraction_maxion_ac__9
#            0.017230 	for  A_planck
#            0.381517 	for  M
#            0.030724 	for  z_reio
#            0.036871 	for  Omega_Lambda
#            0.037650 	for  Omega_m
#            0.009034 	for  YHe
#            0.043616 	for  100*theta_s
#            0.043616 	for  A_s
#            0.125279 	for  sigma8
#            0.213603 	for  rs_d
#            0.213523 	for  a_eq
#            0.045314 	for  k_eq
#            0.045315 	for  rd_star
#            0.200238 	for  rs_star
#            0.193841 	for  da_star
#            0.004241 	for  z_star
#            0.210436 	for  rs_rec
#            0.209118 	for  da_rec
#            0.061220 	for  z_rec
#            0.297614 	for  age
#            0.068109 	for  theta_star_100
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  -> Computing histograms for  omega_cdm
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  z_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_Lambda
#  -> Computing histograms for  Omega_m
#  -> Computing histograms for  YHe
#  /!\ Polyfit may be poorly conditioned
#  -> Computing histograms for  100*theta_s
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_s
#  -> Computing histograms for  sigma8
#  -> Computing histograms for  rs_d
#  -> Computing histograms for  a_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  k_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rd_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_star
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_star
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_rec
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_rec
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_rec
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  age
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  theta_star_100
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_desi_2025-12-19
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_desi_2025-12-19/2025-12-19_1000000__2.txt: Removed 0 non-markovian points, 33 points of burn-in, keep 1077 steps
#                                                                                                                                                    2025-12-19_1000000__3.txt: Removed 0 non-markovian points, 109 points of burn-in, keep 966 steps
#                                                                                                                                                    2025-12-19_1000000__1.txt: Removed 0 non-markovian points, 11 points of burn-in, keep 1154 steps
#                                                                                                                                                    2025-12-19_1000000__4.txt: Removed 0 non-markovian points, 37 points of burn-in, keep 1208 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 1.026087 	for  H0
#            0.064942 	for  omega_b
#            0.650766 	for  omega_cdm
#            0.058272 	for  ln10^{10}A_s
#            0.226574 	for  n_s
#            0.016570 	for  tau_reio
#            0.012982 	for  fraction_maxion_ac__1
#            0.031221 	for  fraction_maxion_ac__2
#            0.002999 	for  fraction_maxion_ac__3
#            0.186360 	for  fraction_maxion_ac__4
#            0.019383 	for  fraction_maxion_ac__5
#            0.118413 	for  fraction_maxion_ac__6
#            0.046053 	for  fraction_maxion_ac__7
#            0.026785 	for  fraction_maxion_ac__8
#            0.018093 	for  fraction_maxion_ac__9
#            0.028232 	for  A_planck
#            1.084604 	for  M
#            0.018427 	for  z_reio
#            0.053161 	for  Omega_Lambda
#            0.063916 	for  Omega_m
#            0.056406 	for  YHe
#            0.096677 	for  100*theta_s
#            0.096678 	for  A_s
#            0.228826 	for  sigma8
#            0.844512 	for  rs_d
#            0.844112 	for  a_eq
#            0.033598 	for  k_eq
#            0.033599 	for  rd_star
#            0.818284 	for  rs_star
#            0.793451 	for  da_star
#            0.059638 	for  z_star
#            0.828718 	for  rs_rec
#            0.810554 	for  da_rec
#            0.197874 	for  z_rec
#            0.984063 	for  age
#            0.242167 	for  theta_star_100
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  z_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_Lambda
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_m
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  YHe
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  100*theta_s
#  /!\ Polyfit may be poorly conditioned
#  -> Computing histograms for  A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  sigma8
#  -> Computing histograms for  rs_d
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  a_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  k_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rd_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_rec
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  age
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  theta_star_100
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-19
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-19/2025-12-19_1000000__2.txt: Removed 0 non-markovian points, 10 points of burn-in, keep 1170 steps
#                                                                                                                                                          2025-12-19_1000000__3.txt: Removed 0 non-markovian points, 257 points of burn-in, keep 903 steps
#                                                                                                                                                          2025-12-19_1000000__1.txt: Removed 0 non-markovian points, 10 points of burn-in, keep 1090 steps
#                                                                                                                                                          2025-12-19_1000000__4.txt: Removed 0 non-markovian points, 30 points of burn-in, keep 1115 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.010383 	for  H0
#            0.005088 	for  omega_b
#            0.021000 	for  omega_cdm
#            0.003701 	for  ln10^{10}A_s
#            0.018993 	for  n_s
#            0.007594 	for  tau_reio
#            0.006634 	for  fraction_maxion_ac__1
#            0.044489 	for  fraction_maxion_ac__2
#            0.028366 	for  fraction_maxion_ac__3
#            0.009888 	for  fraction_maxion_ac__4
#            0.015891 	for  fraction_maxion_ac__5
#            0.003078 	for  fraction_maxion_ac__6
#            0.034689 	for  fraction_maxion_ac__7
#            0.121301 	for  fraction_maxion_ac__8
#            0.139530 	for  fraction_maxion_ac__9
#            0.008160 	for  A_planck
#            0.012029 	for  M
#            0.008040 	for  z_reio
#            0.005835 	for  Omega_Lambda
#            0.004853 	for  Omega_m
#            0.004856 	for  YHe
#            0.034045 	for  100*theta_s
#            0.034046 	for  A_s
#            0.008948 	for  sigma8
#            0.017524 	for  rs_d
#            0.017522 	for  a_eq
#            0.015496 	for  k_eq
#            0.015496 	for  rd_star
#            0.018180 	for  rs_star
#            0.018052 	for  da_star
#            0.007896 	for  z_star
#            0.018309 	for  rs_rec
#            0.018259 	for  da_rec
#            0.016359 	for  z_rec
#            0.015874 	for  age
#            0.016451 	for  theta_star_100
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  -> Computing histograms for  tau_reio
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  z_reio
#  -> Computing histograms for  Omega_Lambda
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_m
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  YHe
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  100*theta_s
#  /!\ Polyfit may be poorly conditioned
#  -> Computing histograms for  A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  sigma8
#  -> Computing histograms for  rs_d
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  a_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  k_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rd_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_star
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_rec
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_rec
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  age
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  theta_star_100
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_boss_2025-12-19
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_boss_2025-12-19/2025-12-19_1000000__2.txt: Removed 0 non-markovian points, 1 points of burn-in, keep 1959 steps
#                                                                                                                                                    2025-12-19_1000000__3.txt: Removed 0 non-markovian points, 42 points of burn-in, keep 1768 steps
#                                                                                                                                                    2025-12-19_1000000__1.txt: Removed 0 non-markovian points, 9 points of burn-in, keep 1916 steps
#                                                                                                                                                    2025-12-19_1000000__4.txt: Removed 0 non-markovian points, 0 points of burn-in, keep 1870 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.361058 	for  H0
#            0.097774 	for  omega_b
#            0.174897 	for  omega_cdm
#            0.059958 	for  ln10^{10}A_s
#            0.192064 	for  n_s
#            0.038903 	for  tau_reio
#            0.027303 	for  fraction_maxion_ac__1
#            0.022197 	for  fraction_maxion_ac__2
#            0.004956 	for  fraction_maxion_ac__3
#            0.006919 	for  fraction_maxion_ac__4
#            0.042221 	for  fraction_maxion_ac__5
#            0.058257 	for  fraction_maxion_ac__6
#            0.063740 	for  fraction_maxion_ac__7
#            0.012828 	for  fraction_maxion_ac__8
#            0.008689 	for  fraction_maxion_ac__9
#            0.008534 	for  A_planck
#            0.379432 	for  M
#            0.045062 	for  z_reio
#            0.086174 	for  Omega_Lambda
#            0.094972 	for  Omega_m
#            0.092907 	for  YHe
#            0.025421 	for  100*theta_s
#            0.025422 	for  A_s
#            0.143136 	for  sigma8
#            0.243162 	for  rs_d
#            0.243100 	for  a_eq
#            0.007758 	for  k_eq
#            0.007758 	for  rd_star
#            0.226995 	for  rs_star
#            0.219788 	for  da_star
#            0.014723 	for  z_star
#            0.237506 	for  rs_rec
#            0.235648 	for  da_rec
#            0.054386 	for  z_rec
#            0.300555 	for  age
#            0.102678 	for  theta_star_100
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  -> Computing histograms for  ln10^{10}A_s
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
# ...
#  -> Computing histograms for  k_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rd_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_rec
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  age
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  theta_star_100
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_axions/planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-23
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_axions/planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-23/2025-12-23_1000000__1.txt: Removed 0 non-markovian points, 194 points of burn-in, keep 201 steps
#                                                                                                                                                          2025-12-23_1000000__2.txt: Removed 0 non-markovian points, 130 points of burn-in, keep 175 steps
#                                                                                                                                                          2025-12-23_1000000__3.txt: Removed everything: chain not converged
#                                                                                                                                                          2025-12-23_1000000__4.txt: Removed 0 non-markovian points, 291 points of burn-in, keep 74 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.484066 	for  H0
#            0.141068 	for  omega_b
#            0.159451 	for  omega_cdm
#            0.050671 	for  ln10^{10}A_s
#            0.046380 	for  n_s
#            0.046070 	for  tau_reio
#            0.855683 	for  fraction_maxion_ac__1
#            0.165147 	for  fraction_maxion_ac__2
#            0.087988 	for  fraction_maxion_ac__3
#            0.016624 	for  fraction_maxion_ac__4
#            4.248412 	for  log10_maxion_ac__1
#            4.568244 	for  log10_maxion_ac__2
#            1.808636 	for  log10_maxion_ac__3
#            0.830781 	for  log10_maxion_ac__4
#            0.025851 	for  A_planck
#            0.449506 	for  M
#            0.041452 	for  z_reio
#            0.037381 	for  Omega_Lambda
#            0.032678 	for  Omega_m
#            0.116805 	for  YHe
#            0.026172 	for  100*theta_s
#            0.026173 	for  A_s
#            0.036847 	for  sigma8
#            0.313093 	for  rs_d
#            0.313102 	for  a_eq
#            0.049722 	for  k_eq
#            0.049725 	for  rd_star
#            0.283822 	for  rs_star
#            0.273411 	for  da_star
#            0.064933 	for  z_star
#            0.285619 	for  rs_rec
#            0.276881 	for  da_rec
#            0.040624 	for  z_rec
#            0.463431 	for  age
#            0.212069 	for  theta_star_100
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  log10_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  log10_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  log10_maxion_ac__3
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  log10_maxion_ac__4
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  z_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_Lambda
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_m
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  YHe
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  100*theta_s
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  sigma8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rs_d
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  a_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  k_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rd_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_rec
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  age
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  theta_star_100
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files

# %%
import fitz  # PyMuPDF
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

base = Path("/Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions")
base2 = Path("/Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_axions")


chains = [
        "planck_TTTEEElensing_pantheon_plus_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_desi_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_boss_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_sh0es_boss_2025-12-19",
         ]

chains2 = [
        "planck_TTTEEElensing_pantheon_plus_2025-12-23",
        "planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-23",
        "planck_TTTEEElensing_pantheon_plus_desi_2025-12-23",
        "planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-23",
         ]

for chain_name in chains:
    chain_dir = base / chain_name / "plots"
    chain_dir2 = base2 / chain_name / "plots"
    pdfs = list(chain_dir.glob("*.pdf"))
    pdfs2 = list(chain_dir2.glob("*.pdf"))

    if not pdfs:
        print(f"No PDFs found in {chain_dir}")
        continue
    if not pdfs2:
        print(f"No PDFs found in {chain_dir}")
        continue

    for pdf_path in pdfs:
        print(f"Displaying {pdf_path.name}")
        doc = fitz.open(pdf_path)
        for page_num in range(len(doc)):
            page = doc.load_page(page_num)
            pix = page.get_pixmap()  # Render page to pixmap
            img = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)  # Convert to array

            plt.figure(figsize=(12, 8))
            plt.imshow(img)
            plt.axis('off')
            plt.show()

    for pdf_path in pdfs2:
        print(f"Displaying {pdf_path.name}")
        doc = fitz.open(pdf_path)
        for page_num in range(len(doc)):
            page = doc.load_page(page_num)
            pix = page.get_pixmap()  # Render page to pixmap
            img = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)  # Convert to array

            plt.figure(figsize=(12, 8))
            plt.imshow(img)
            plt.axis('off')
            plt.show()
# Out:
# No PDFs found in /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_2025-12-19/plots
# No PDFs found in /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-19/plots
# No PDFs found in /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_desi_2025-12-19/plots
# No PDFs found in /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-19/plots
# No PDFs found in /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_boss_2025-12-19/plots
# No PDFs found in /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_boss_2025-12-19/plots
