# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import to_hex
from matplotlib import colormaps

from procoli import lkl_prof
from procoli.procoli_io import get_MP_bf_dict
from procoli.procoli_plots import plot_profile_list, plot_profile_and_parabola_diff_list, get_SA_step_chains_chi2, plot_SA_min_chains, get_SA_step_chains, plot_SA_chains

# %matplotlib inline
# Out:
# /Users/bellamarco01/.pyenv/versions/3.13.5/lib/python3.13/site-packages/procoli/mp_procoli_functions.py:288: SyntaxWarning: invalid escape sequence '\ '
#   /!\ THIS FUNCTION DOESN'T ACTUALLY LEAD TO CONVERGENCE. NEEDS IMPROVEMENT.
# /Users/bellamarco01/.pyenv/versions/3.13.5/lib/python3.13/site-packages/procoli/mp_procoli_functions.py:933: SyntaxWarning: invalid escape sequence '\D'
#   :return: True if j < \Delta \theta_i / \sigma_i
# /Users/bellamarco01/.pyenv/versions/3.13.5/lib/python3.13/site-packages/procoli/mp_procoli_functions.py:1332: SyntaxWarning: invalid escape sequence '\ '
#   /!\ File naming scheme hard-coded within this function.

# %%
from pathlib import Path

BASE = Path(
    "/Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/varying_zc"
)

# # 1 axion
chain_1pd  = BASE / "planck_TTTEEElensing_pantheon_plus_desi_2026-01-14"

lcdm_H0 = lkl_prof(chain_1pd, 'H0')

# %%
lcdm_H0.prof_incr = 0.1
lcdm_H0.prof_max = 75.
lcdm_H0.prof_min = 68.
lcdm_H0.processes = 2

# %%
lcdm_H0.global_min(N_min_steps=4000);
# Out:
# check_global_min: Found minimum with file name planck_TTTEEElensing_pantheon_plus_desi_2026-01-14
# check_global_min: Found covmat with file name planck_TTTEEElensing_pantheon_plus_desi_2026-01-14
# /Users/bellamarco01/.pyenv/versions/3.13.5/lib/python3.13/site-packages/procoli/mp_procoli_functions.py:288: SyntaxWarning: invalid escape sequence '\ '
#   /!\ THIS FUNCTION DOESN'T ACTUALLY LEAD TO CONVERGENCE. NEEDS IMPROVEMENT.
# /Users/bellamarco01/.pyenv/versions/3.13.5/lib/python3.13/site-packages/procoli/mp_procoli_functions.py:933: SyntaxWarning: invalid escape sequence '\D'
#   :return: True if j < \Delta \theta_i / \sigma_i
# /Users/bellamarco01/.pyenv/versions/3.13.5/lib/python3.13/site-packages/procoli/mp_procoli_functions.py:1332: SyntaxWarning: invalid escape sequence '\ '
#   /!\ File naming scheme hard-coded within this function.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 lcdm_H0.global_min(N_min_steps=4000);
#
# File ~/.pyenv/versions/3.13.5/lib/python3.13/site-packages/procoli/mp_procoli_functions.py:451, in lkl_prof.global_min(self, run_glob_min, N_min_steps, run_minuit)
#     417 """
#     418 Check global minizer, run if wanted (default False), then write if not
#     419     already written
#    (...)    446 :return: global maximum lkl dictionary
#     447 """
#     449 # check to see if the global min exists already
#     450 # and decide to run the minimizer accordingly
# --> 451 global_min_exists, global_min_is_better = self.check_global_min()
#     452 if run_glob_min is None:
#     453     if global_min_is_better:
#
# File ~/.pyenv/versions/3.13.5/lib/python3.13/site-packages/procoli/mp_procoli_functions.py:387, in lkl_prof.check_global_min(self, mcmc_chains)
#     385 else:
#     386     if not os.path.exists(f'{self.chains_dir}{self.info_root}.log'):
# --> 387         self.make_log_file( bf_file=f'{self.chains_dir}{self.info_root}.bestfit',
#     388                             output_loc=self.chains_dir
#     389                           )
#     391 global_min_exists = True
#     392 existing_min = True
#
# File ~/.pyenv/versions/3.13.5/lib/python3.13/site-packages/procoli/mp_procoli_functions.py:1312, in lkl_prof.make_log_file(self, bf_file, output_loc, output_log_file)
#    1309 self.get_experiments()
#    1311 # Run MP at this point and get chi2 values from output as dict
# -> 1312 chi2_per_exp_output = self.MP_run_chi2_per_exp_at_point(
#    1313     output_dir=output_loc,
#    1314     param_point_bf_file=bf_file
#    1315 )
#    1316 # print(chi2_per_exp_output)
#    1317 chi2eff_values = self.get_chi2_per_exp_dict(chi2_per_exp_output)
#
# File ~/.pyenv/versions/3.13.5/lib/python3.13/site-packages/procoli/mp_procoli_functions.py:1152, in lkl_prof.MP_run_chi2_per_exp_at_point(self, output_dir, param_point_bf_file)
#    1130 """
#    1131 Run MontePython to calculate and display chi^2 values for each likelihood
#    1132 at a specific parameter point.
#    (...)   1148 "... -> for Planck_highl_TTTEEE : ... chi2eff= 123.45 ... -> for Planck_lowl_EE : ... chi2eff= 67.89 ..."
#    1149 """
#    1150 mp_run_command = 'MontePython.py run -N 1 -f 0 --display-each-chi2 '\
#    1151 f'-o {output_dir} -p {self.chains_dir}log.param -b {param_point_bf_file}'
# -> 1152 captured_output = run(mp_run_command, shell=True, check=True,
#    1153                       capture_output=True).stdout
#    1154 # Turn our b-string into a normal string
#    1155 chi2_per_exp_output = captured_output.decode('utf-8')
#
# File ~/.pyenv/versions/3.13.5/lib/python3.13/subprocess.py:577, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     575     retcode = process.poll()
#     576     if check and retcode:
# --> 577         raise CalledProcessError(retcode, process.args,
#     578                                  output=stdout, stderr=stderr)
#     579 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command 'MontePython.py run -N 1 -f 0 --display-each-chi2 -o /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/varying_zc/planck_TTTEEElensing_pantheon_plus_desi_2026-01-14/ -p /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/varying_zc/planck_TTTEEElensing_pantheon_plus_desi_2026-01-14/log.param -b /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/varying_zc/planck_TTTEEElensing_pantheon_plus_desi_2026-01-14/planck_TTTEEElensing_pantheon_plus_desi_2026-01-14.bestfit' returned non-zero exit status 1.
