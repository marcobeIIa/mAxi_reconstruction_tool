# %% [markdown]
# # MCMC analysis notebook
# ## using the vanilla MontePython analysis tools
# (there si another notebook using getdist, getdist_mcmc.ipynb, which should be preferred. this notebook was used for simplicity, and is now legacy)

# %%
import subprocess
from pathlib import Path

bases = ["/Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/", "/Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_axions"]

chains = [
        "planck_TTTEEElensing_pantheon_plus_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_desi_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_boss_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_sh0es_boss_2025-12-19",
         ]

chains2 = [
        "planck_TTTEEElensing_2025-12-23",
        "planck_TTTEEElensing_pantheon_plus_2025-12-23",
        "planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-23",
        "planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-23",
         ]

for chain in chains:
    cmd = [
        "python",
        "/Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py",
        "info",
        str(Path(bases[0]) / chain)
    ]
    print("Running:", " ".join(cmd))
    subprocess.run(cmd, check=True)

for chain in chains2:
    cmd = [
        "python",
        "/Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py",
        "info",
        str(Path(bases[1]) / chain)
    ]
    print("Running:", " ".join(cmd))
    subprocess.run(cmd, check=True)
# Out:
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_2025-12-19
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_2025-12-19/2025-12-19_1000000__2.txt: Removed 0 non-markovian points, 92 points of burn-in, keep 1013 steps
#                                                                                                                                               2025-12-19_1000000__3.txt: Removed 0 non-markovian points, 8 points of burn-in, keep 1132 steps
#                                                                                                                                               2025-12-19_1000000__1.txt: Removed 0 non-markovian points, 122 points of burn-in, keep 908 steps
#                                                                                                                                               2025-12-19_1000000__4.txt: Removed 0 non-markovian points, 134 points of burn-in, keep 901 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.549127 	for  H0
#            0.246544 	for  omega_b
#            0.086847 	for  omega_cdm
#            0.017653 	for  ln10^{10}A_s
#            0.146728 	for  n_s
#            0.011207 	for  tau_reio
#            0.102567 	for  fraction_maxion_ac__1
#            0.009823 	for  fraction_maxion_ac__2
#            0.053941 	for  fraction_maxion_ac__3
#            0.030110 	for  fraction_maxion_ac__4
#            0.123981 	for  fraction_maxion_ac__5
#            0.011432 	for  fraction_maxion_ac__6
#            0.010625 	for  fraction_maxion_ac__7
#            0.037398 	for  fraction_maxion_ac__8
#            0.025763 	for  fraction_maxion_ac__9
#            0.006686 	for  A_planck
#            0.593688 	for  M
#            0.015980 	for  z_reio
#            0.128511 	for  Omega_Lambda
#            0.151790 	for  Omega_m
#            0.237415 	for  YHe
#            0.013105 	for  100*theta_s
#            0.013105 	for  A_s
#            0.046461 	for  sigma8
#            0.178224 	for  rs_d
#            0.178180 	for  a_eq
#            0.017784 	for  k_eq
#            0.017784 	for  rd_star
#            0.162419 	for  rs_star
#            0.156438 	for  da_star
#            0.025638 	for  z_star
#            0.168103 	for  rs_rec
#            0.165010 	for  da_rec
#            0.117445 	for  z_rec
#            0.329158 	for  age
#            0.088605 	for  theta_star_100
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  z_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_Lambda
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_m
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  YHe
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  100*theta_s
#  /!\ Polyfit may be poorly conditioned
#  -> Computing histograms for  A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  sigma8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rs_d
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  a_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  k_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rd_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_star
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_rec
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  age
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  theta_star_100
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-19
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-19/2025-12-19_1000000__2.txt: Removed 0 non-markovian points, 2 points of burn-in, keep 1008 steps
#                                                                                                                                                     2025-12-19_1000000__3.txt: Removed 0 non-markovian points, 76 points of burn-in, keep 1044 steps
#                                                                                                                                                     2025-12-19_1000000__1.txt: Removed 0 non-markovian points, 134 points of burn-in, keep 906 steps
#                                                                                                                                                     2025-12-19_1000000__4.txt: Removed 0 non-markovian points, 15 points of burn-in, keep 940 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.461041 	for  H0
#            0.015033 	for  omega_b
#            0.202072 	for  omega_cdm
#            0.065177 	for  ln10^{10}A_s
#            0.149377 	for  n_s
#            0.018425 	for  tau_reio
#            0.038226 	for  fraction_maxion_ac__1
#            0.000407 	for  fraction_maxion_ac__2
#            0.131452 	for  fraction_maxion_ac__3
#            0.048075 	for  fraction_maxion_ac__4
#            0.037047 	for  fraction_maxion_ac__5
#            0.032511 	for  fraction_maxion_ac__6
#            0.044680 	for  fraction_maxion_ac__7
#            0.060878 	for  fraction_maxion_ac__8
#            0.011955 	for  fraction_maxion_ac__9
#            0.022285 	for  A_planck
#            0.483687 	for  M
#            0.028311 	for  z_reio
#            0.029350 	for  Omega_Lambda
#            0.029623 	for  Omega_m
#            0.009874 	for  YHe
#            0.053299 	for  100*theta_s
#            0.053300 	for  A_s
#            0.157659 	for  sigma8
#            0.292462 	for  rs_d
#            0.292407 	for  a_eq
#            0.053736 	for  k_eq
#            0.053737 	for  rd_star
#            0.274432 	for  rs_star
#            0.265643 	for  da_star
#            0.007099 	for  z_star
#            0.288870 	for  rs_rec
#            0.287294 	for  da_rec
#            0.087006 	for  z_rec
#            0.405339 	for  age
#            0.133970 	for  theta_star_100
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  z_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_Lambda
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_m
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  YHe
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  100*theta_s
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_s
#  -> Computing histograms for  sigma8
#  -> Computing histograms for  rs_d
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  a_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  k_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rd_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_rec
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  age
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  theta_star_100
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_desi_2025-12-19
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_desi_2025-12-19/2025-12-19_1000000__2.txt: Removed 0 non-markovian points, 33 points of burn-in, keep 802 steps
#                                                                                                                                                    2025-12-19_1000000__3.txt: Removed 0 non-markovian points, 109 points of burn-in, keep 711 steps
#                                                                                                                                                    2025-12-19_1000000__1.txt: Removed 0 non-markovian points, 11 points of burn-in, keep 849 steps
#                                                                                                                                                    2025-12-19_1000000__4.txt: Removed 0 non-markovian points, 37 points of burn-in, keep 908 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 1.082610 	for  H0
#            0.039155 	for  omega_b
#            0.520969 	for  omega_cdm
#            0.019664 	for  ln10^{10}A_s
#            0.315111 	for  n_s
#            0.006820 	for  tau_reio
#            0.003912 	for  fraction_maxion_ac__1
#            0.034926 	for  fraction_maxion_ac__2
#            0.004735 	for  fraction_maxion_ac__3
#            0.130459 	for  fraction_maxion_ac__4
#            0.072858 	for  fraction_maxion_ac__5
#            0.143782 	for  fraction_maxion_ac__6
#            0.041994 	for  fraction_maxion_ac__7
#            0.033824 	for  fraction_maxion_ac__8
#            0.007973 	for  fraction_maxion_ac__9
#            0.034861 	for  A_planck
#            1.166928 	for  M
#            0.004990 	for  z_reio
#            0.022884 	for  Omega_Lambda
#            0.030818 	for  Omega_m
#            0.029399 	for  YHe
#            0.099814 	for  100*theta_s
#            0.099815 	for  A_s
#            0.158977 	for  sigma8
#            0.739939 	for  rs_d
#            0.739635 	for  a_eq
#            0.031224 	for  k_eq
#            0.031224 	for  rd_star
#            0.709852 	for  rs_star
#            0.678956 	for  da_star
#            0.049841 	for  z_star
#            0.718766 	for  rs_rec
#            0.693268 	for  da_rec
#            0.138079 	for  z_rec
#            0.919375 	for  age
#            0.253400 	for  theta_star_100
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  z_reio
#  -> Computing histograms for  Omega_Lambda
#  -> Computing histograms for  Omega_m
#  -> Computing histograms for  YHe
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  100*theta_s
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  sigma8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rs_d
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  a_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  k_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rd_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_rec
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  age
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  theta_star_100
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-19
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-19/2025-12-19_1000000__2.txt: Removed 0 non-markovian points, 10 points of burn-in, keep 875 steps
#                                                                                                                                                          2025-12-19_1000000__3.txt: Removed 0 non-markovian points, 257 points of burn-in, keep 633 steps
#                                                                                                                                                          2025-12-19_1000000__1.txt: Removed 0 non-markovian points, 10 points of burn-in, keep 840 steps
#                                                                                                                                                          2025-12-19_1000000__4.txt: Removed 0 non-markovian points, 30 points of burn-in, keep 840 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.091846 	for  H0
#            0.003107 	for  omega_b
#            0.059523 	for  omega_cdm
#            0.002832 	for  ln10^{10}A_s
#            0.052533 	for  n_s
#            0.005238 	for  tau_reio
#            0.030716 	for  fraction_maxion_ac__1
#            0.048884 	for  fraction_maxion_ac__2
#            0.040908 	for  fraction_maxion_ac__3
#            0.005001 	for  fraction_maxion_ac__4
#            0.040437 	for  fraction_maxion_ac__5
#            0.014516 	for  fraction_maxion_ac__6
#            0.028607 	for  fraction_maxion_ac__7
#            0.149012 	for  fraction_maxion_ac__8
#            0.307931 	for  fraction_maxion_ac__9
#            0.029331 	for  A_planck
#            0.095668 	for  M
#            0.007987 	for  z_reio
#            0.011600 	for  Omega_Lambda
#            0.013895 	for  Omega_m
#            0.002099 	for  YHe
#            0.108390 	for  100*theta_s
#            0.108392 	for  A_s
#            0.019911 	for  sigma8
#            0.072599 	for  rs_d
#            0.072582 	for  a_eq
#            0.011016 	for  k_eq
#            0.011017 	for  rd_star
#            0.070397 	for  rs_star
#            0.065416 	for  da_star
#            0.001173 	for  z_star
#            0.073603 	for  rs_rec
#            0.070077 	for  da_rec
#            0.024213 	for  z_rec
#            0.082012 	for  age
#            0.042190 	for  theta_star_100
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  z_reio
#  -> Computing histograms for  Omega_Lambda
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_m
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  YHe
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  100*theta_s
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  sigma8
#  -> Computing histograms for  rs_d
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  a_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  k_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rd_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_rec
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  age
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  theta_star_100
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_boss_2025-12-19
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_boss_2025-12-19/2025-12-19_1000000__2.txt: Removed 0 non-markovian points, 1 points of burn-in, keep 1104 steps
#                                                                                                                                                    2025-12-19_1000000__3.txt: Removed 0 non-markovian points, 31 points of burn-in, keep 974 steps
# ...
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_rec
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  age
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  theta_star_100
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_axions/planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-23
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_axions/planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-23/2025-12-23_1000000__1.txt: Removed 0 non-markovian points, 190 points of burn-in, keep 15 steps
#                                                                                                                                                          2025-12-23_1000000__2.txt: Removed 0 non-markovian points, 119 points of burn-in, keep 56 steps
#                                                                                                                                                          2025-12-23_1000000__3.txt: Removed everything: chain not converged
#                                                                                                                                                          2025-12-23_1000000__4.txt: Removed everything: chain not converged
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.425797 	for  H0
#            1.375065 	for  omega_b
#            0.034484 	for  omega_cdm
#            0.343611 	for  ln10^{10}A_s
#            0.137999 	for  n_s
#            0.387504 	for  tau_reio
#            0.050730 	for  fraction_maxion_ac__1
#            0.536045 	for  fraction_maxion_ac__2
#            0.039460 	for  fraction_maxion_ac__3
#            0.161704 	for  fraction_maxion_ac__4
#            21.009812 	for  log10_maxion_ac__1
#            0.004178 	for  log10_maxion_ac__2
#            0.202488 	for  log10_maxion_ac__3
#            0.558359 	for  log10_maxion_ac__4
#            0.004159 	for  A_planck
#            20.370129 	for  M
#            0.483664 	for  z_reio
#            0.463628 	for  Omega_Lambda
#            0.167166 	for  Omega_m
#            0.787657 	for  YHe
#            0.049628 	for  100*theta_s
#            0.049647 	for  A_s
#            0.557275 	for  sigma8
#            0.034280 	for  rs_d
#            0.034294 	for  a_eq
#            0.079432 	for  k_eq
#            0.079462 	for  rd_star
#            0.021178 	for  rs_star
#            0.018122 	for  da_star
#            0.031241 	for  z_star
#            0.011207 	for  rs_rec
#            0.006381 	for  da_rec
#            0.552969 	for  z_rec
#            0.081710 	for  age
#            0.082392 	for  theta_star_100
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  log10_maxion_ac__1
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  log10_maxion_ac__2
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  log10_maxion_ac__3
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  log10_maxion_ac__4
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  z_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_Lambda
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  Omega_m
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  YHe
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  100*theta_s
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  sigma8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rs_d
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  a_eq
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  k_eq
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  rd_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  /!\ Attempting to set identical low and high ylims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_star
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_star
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  rs_rec
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  da_rec
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  z_rec
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  age
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
#  -> Computing histograms for  theta_star_100
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  /!\ Attempting to set identical low and high xlims makes transformation
#      singular; automatically expanding.
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files

# %%
import fitz  # PyMuPDF
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

base = Path("/Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions")
base2 = Path("/Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_axions")


chains = [
        "planck_TTTEEElensing_pantheon_plus_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_desi_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_boss_2025-12-19",
        "planck_TTTEEElensing_pantheon_plus_sh0es_boss_2025-12-19",
         ]

chains2 = [
        "planck_TTTEEElensing_pantheon_plus_2025-12-23",
        "planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-23",
        "planck_TTTEEElensing_pantheon_plus_desi_2025-12-23",
        "planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-23",
         ]

for chain_name in chains:
    chain_dir = base / chain_name / "plots"
    chain_dir2 = base2 / chain_name / "plots"
    pdfs = list(chain_dir.glob("*.pdf"))
    pdfs2 = list(chain_dir2.glob("*.pdf"))

    if not pdfs:
        print(f"No PDFs found in {chain_dir}")
        continue
    if not pdfs2:
        print(f"No PDFs found in {chain_dir}")
        continue

    for pdf_path in pdfs:
        print(f"Displaying {pdf_path.name}")
        doc = fitz.open(pdf_path)
        for page_num in range(len(doc)):
            page = doc.load_page(page_num)
            pix = page.get_pixmap()  # Render page to pixmap
            img = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)  # Convert to array

            plt.figure(figsize=(12, 8))
            plt.imshow(img)
            plt.axis('off')
            plt.show()

    for pdf_path in pdfs2:
        print(f"Displaying {pdf_path.name}")
        doc = fitz.open(pdf_path)
        for page_num in range(len(doc)):
            page = doc.load_page(page_num)
            pix = page.get_pixmap()  # Render page to pixmap
            img = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)  # Convert to array

            plt.figure(figsize=(12, 8))
            plt.imshow(img)
            plt.axis('off')
            plt.show()
# Out:
# No PDFs found in /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_2025-12-19/plots
# No PDFs found in /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_2025-12-19/plots
# No PDFs found in /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_desi_2025-12-19/plots
# No PDFs found in /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_desi_2025-12-19/plots
# No PDFs found in /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_boss_2025-12-19/plots
# No PDFs found in /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_axions/planck_TTTEEElensing_pantheon_plus_sh0es_boss_2025-12-19/plots
