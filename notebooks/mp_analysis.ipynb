# %%
import subprocess
from pathlib import Path

base = Path("/Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp")

chains = [
         "4_ax_planck_TTTEEElensing_pantheon_plus2025-11-12",
         "4_ax_planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12",
         "9_ax_planck_TTTEEElensing_pantheon_plus_desi2025-11-12",
         "9_ax_planck_TTTEEElensing_pantheon_plus_sh0es_desi2025-11-12",
         "planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12",
         "planck_TTTEEElensing_pantheon_plus2025-11-12",
         ]

for chain in chains:
    cmd = [
        "python",
        "/Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py",
        "info",
        str(base/chain)
    ]
    print("Running:", " ".join(cmd))
    subprocess.run(cmd, check=True)
# Out:
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_ax_planck_TTTEEElensing_pantheon_plus2025-11-12
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_ax_planck_TTTEEElensing_pantheon_plus2025-11-12/2025-11-12_1000000__4.txt: Removed 0 non-markovian points, 109 points of burn-in, keep 2051 steps
#                                                                                                                                          2025-11-12_1000000__2.txt: Removed 0 non-markovian points, 218 points of burn-in, keep 1932 steps
#                                                                                                                                          2025-11-12_1000000__3.txt: Removed 0 non-markovian points, 550 points of burn-in, keep 1530 steps
#                                                                                                                                          2025-11-12_1000000__1.txt: Removed 0 non-markovian points, 145 points of burn-in, keep 1885 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 2.125974 	for  H0
#            0.163437 	for  omega_b
#            0.378689 	for  omega_cdm
#            0.064456 	for  ln10^{10}A_s
#            0.392940 	for  n_s
#            0.035178 	for  tau_reio
#            0.051894 	for  fraction_maxion_ac__1
#            1.566458 	for  fraction_maxion_ac__2
#            0.092525 	for  fraction_maxion_ac__3
#            0.039382 	for  fraction_maxion_ac__4
#            0.002611 	for  A_planck
#            2.428675 	for  M
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_ax_planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_ax_planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12/2025-11-12_1000000__4.txt: Removed 0 non-markovian points, 2285 points of burn-in, keep 70 steps
#                                                                                                                                                2025-11-12_1000000__2.txt: Removed 0 non-markovian points, 1367 points of burn-in, keep 593 steps
#                                                                                                                                                2025-11-12_1000000__3.txt: Removed everything: chain not converged
#                                                                                                                                                2025-11-12_1000000__1.txt: Removed everything: chain not converged
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 1.028361 	for  H0
#            0.104553 	for  omega_b
#            0.012621 	for  omega_cdm
#            0.002269 	for  ln10^{10}A_s
#            0.204003 	for  n_s
#            0.004710 	for  tau_reio
#            0.220242 	for  fraction_maxion_ac__1
#            0.139718 	for  fraction_maxion_ac__2
#            0.003722 	for  fraction_maxion_ac__3
#            0.158480 	for  fraction_maxion_ac__4
#            0.032326 	for  A_planck
#            3.007824 	for  M
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_ax_planck_TTTEEElensing_pantheon_plus_desi2025-11-12
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_ax_planck_TTTEEElensing_pantheon_plus_desi2025-11-12/2025-11-12_10000__2.txt: Removed 0 non-markovian points, 208 points of burn-in, keep 590 steps
#                                                                                                                                               2025-11-12_10000__3.txt: Removed 0 non-markovian points, 142 points of burn-in, keep 656 steps
#                                                                                                                                               2025-11-12_10000__1.txt: Removed 0 non-markovian points, 252 points of burn-in, keep 455 steps
#                                                                                                                                               2025-11-12_10000__4.txt: Removed 0 non-markovian points, 313 points of burn-in, keep 181 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 2.144518 	for  H0
#            0.446076 	for  omega_b
#            0.764274 	for  omega_cdm
#            0.054343 	for  ln10^{10}A_s
#            0.488403 	for  n_s
#            0.090400 	for  tau_reio
#            0.073012 	for  fraction_maxion_ac__1
#            0.109064 	for  fraction_maxion_ac__2
#            0.294609 	for  fraction_maxion_ac__3
#            0.642256 	for  fraction_maxion_ac__4
#            0.267373 	for  fraction_maxion_ac__5
#            0.719121 	for  fraction_maxion_ac__6
#            0.367709 	for  fraction_maxion_ac__7
#            0.123532 	for  fraction_maxion_ac__8
#            0.096566 	for  fraction_maxion_ac__9
#            0.019956 	for  A_planck
#            2.856863 	for  M
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_ax_planck_TTTEEElensing_pantheon_plus_sh0es_desi2025-11-12
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_ax_planck_TTTEEElensing_pantheon_plus_sh0es_desi2025-11-12/2025-11-12_1000000__4.txt: Removed 0 non-markovian points, 335 points of burn-in, keep 935 steps
#                                                                                                                                                     2025-11-12_1000000__2.txt: Removed 0 non-markovian points, 1018 points of burn-in, keep 287 steps
#                                                                                                                                                     2025-11-12_1000000__3.txt: Removed 0 non-markovian points, 682 points of burn-in, keep 513 steps
#                                                                                                                                                     2025-11-12_1000000__1.txt: Removed everything: chain not converged
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.056435 	for  H0
#            0.288155 	for  omega_b
#            0.476146 	for  omega_cdm
#            0.009447 	for  ln10^{10}A_s
#            0.011367 	for  n_s
#            0.025259 	for  tau_reio
#            0.029932 	for  fraction_maxion_ac__1
#            0.004785 	for  fraction_maxion_ac__2
#            0.105922 	for  fraction_maxion_ac__3
#            0.428278 	for  fraction_maxion_ac__4
#            0.141575 	for  fraction_maxion_ac__5
#            0.105563 	for  fraction_maxion_ac__6
#            0.150014 	for  fraction_maxion_ac__7
#            0.574992 	for  fraction_maxion_ac__8
#            0.273120 	for  fraction_maxion_ac__9
#            0.033010 	for  A_planck
#            0.077956 	for  M
# -----------------------------------------------
#  -> Computing histograms for  H0
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12/2025-11-12_1000000__8.txt: Removed everything: chain not converged
#                                                                                                                                           2025-11-12_1000000__4.txt: Removed everything: chain not converged
#                                                                                                                                           2025-11-12_1000000__5.txt: Removed 0 non-markovian points, 705 points of burn-in, keep 570 steps
#                                                                                                                                           2025-11-12_1000000__7.txt: Removed everything: chain not converged
#                                                                                                                                           2025-11-12_1000000__6.txt: Removed 0 non-markovian points, 783 points of burn-in, keep 387 steps
#                                                                                                                                           2025-11-12_1000000__2.txt: Removed everything: chain not converged
#                                                                                                                                           2025-11-12_1000000__3.txt: Removed everything: chain not converged
#                                                                                                                                           2025-11-12_1000000__1.txt: Removed everything: chain not converged
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.859645 	for  H0
#            0.438350 	for  omega_b
#            0.367588 	for  omega_cdm
#            0.047525 	for  ln10^{10}A_s
#            0.618399 	for  n_s
#            0.031945 	for  tau_reio
#            1.538669 	for  fraction_maxion_ac__1
#            0.258813 	for  fraction_maxion_ac__2
#            0.048917 	for  fraction_maxion_ac__3
#            0.078918 	for  fraction_maxion_ac__4
#            0.162671 	for  fraction_maxion_ac__5
#            0.079015 	for  fraction_maxion_ac__6
#            0.082810 	for  fraction_maxion_ac__7
#            0.098352 	for  fraction_maxion_ac__8
#            0.624801 	for  fraction_maxion_ac__9
#            0.000648 	for  A_planck
#            1.114589 	for  M
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/planck_TTTEEElensing_pantheon_plus2025-11-12
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/planck_TTTEEElensing_pantheon_plus2025-11-12/2025-11-12_1000000__8.txt: Removed 0 non-markovian points, 1199 points of burn-in, keep 641 steps
#                                                                                                                                     2025-11-12_1000000__4.txt: Removed everything: chain not converged
#                                                                                                                                     2025-11-12_1000000__5.txt: Removed 0 non-markovian points, 363 points of burn-in, keep 732 steps
#                                                                                                                                     2025-11-12_1000000__7.txt: Removed 0 non-markovian points, 576 points of burn-in, keep 639 steps
#                                                                                                                                     2025-11-12_1000000__6.txt: Removed 0 non-markovian points, 291 points of burn-in, keep 884 steps
#                                                                                                                                     2025-11-12_1000000__3.txt: Removed everything: chain not converged
#                                                                                                                                     2025-11-12_1000000__1.txt: Removed everything: chain not converged
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 1.576789 	for  H0
#            1.384222 	for  omega_b
#            1.126523 	for  omega_cdm
#            0.218225 	for  ln10^{10}A_s
#            0.338166 	for  n_s
#            0.293313 	for  tau_reio
#            0.031434 	for  fraction_maxion_ac__1
#            0.016638 	for  fraction_maxion_ac__2
#            0.179784 	for  fraction_maxion_ac__3
#            0.305384 	for  fraction_maxion_ac__4
#            0.174729 	for  fraction_maxion_ac__5
#            0.459077 	for  fraction_maxion_ac__6
#            0.183998 	for  fraction_maxion_ac__7
#            0.118160 	for  fraction_maxion_ac__8
#            0.118772 	for  fraction_maxion_ac__9
#            0.095412 	for  A_planck
#            1.783264 	for  M
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files

# %%
import fitz  # PyMuPDF
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

base = Path("/Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp")

chains = [
         "4_ax_planck_TTTEEElensing_pantheon_plus2025-11-12",
         "4_ax_planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12",
         "9_ax_planck_TTTEEElensing_pantheon_plus_desi2025-11-12",
         "9_ax_planck_TTTEEElensing_pantheon_plus_sh0es_desi2025-11-12",
         "planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12",
         "planck_TTTEEElensing_pantheon_plus2025-11-12",
         ]
for chain_name in chains:
    chain_dir = base / chain_name / "plots"
    pdfs = list(chain_dir.glob("*.pdf"))

    if not pdfs:
        print(f"No PDFs found in {chain_dir}")
        continue

    for pdf_path in pdfs:
        print(f"Displaying {pdf_path.name}")
        doc = fitz.open(pdf_path)
        for page_num in range(len(doc)):
            page = doc.load_page(page_num)
            pix = page.get_pixmap()  # Render page to pixmap
            img = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)  # Convert to array

            plt.figure(figsize=(12, 8))
            plt.imshow(img)
            plt.axis('off')
            plt.show()
# Out:
# Displaying 4_ax_planck_TTTEEElensing_pantheon_plus2025-11-12_triangle.pdf
# Displaying 4_ax_planck_TTTEEElensing_pantheon_plus2025-11-12_1d.pdf
# Displaying 4_ax_planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12_1d.pdf
# Displaying 4_ax_planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12_triangle.pdf
# Displaying 9_ax_planck_TTTEEElensing_pantheon_plus_desi2025-11-12_1d.pdf
# Displaying 9_ax_planck_TTTEEElensing_pantheon_plus_desi2025-11-12_triangle.pdf
# Displaying 9_ax_planck_TTTEEElensing_pantheon_plus_sh0es_desi2025-11-12_triangle.pdf
# Displaying 9_ax_planck_TTTEEElensing_pantheon_plus_sh0es_desi2025-11-12_1d.pdf
# Displaying planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12_1d.pdf
# Displaying planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12_triangle.pdf
# Displaying planck_TTTEEElensing_pantheon_plus2025-11-12_triangle.pdf
# Displaying planck_TTTEEElensing_pantheon_plus2025-11-12_1d.pdf
