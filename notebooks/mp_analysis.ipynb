# %%
import subprocess
from pathlib import Path

base = Path("/Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp")

chains = [
         "4_ax_planck_TTTEEElensing_pantheon_plus2025-11-12",
         "4_ax_planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12",
         "9_ax_planck_TTTEEElensing_pantheon_plus_desi2025-11-12",
         "9_ax_planck_TTTEEElensing_pantheon_plus_sh0es_desi2025-11-12",
         "planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12",
         "planck_TTTEEElensing_pantheon_plus2025-11-12",
         ]

for chain in chains:
    cmd = [
        "python",
        "/Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py",
        "info",
        str(base/chain)
    ]
    print("Running:", " ".join(cmd))
    subprocess.run(cmd, check=True)
# Out:
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_ax_planck_TTTEEElensing_pantheon_plus2025-11-12
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_ax_planck_TTTEEElensing_pantheon_plus2025-11-12/2025-11-12_1000000__4.txt: Removed 0 non-markovian points, 109 points of burn-in, keep 2406 steps
#                                                                                                                                          2025-11-12_1000000__2.txt: Removed 0 non-markovian points, 219 points of burn-in, keep 2226 steps
#                                                                                                                                          2025-11-12_1000000__3.txt: Removed 0 non-markovian points, 550 points of burn-in, keep 1845 steps
#                                                                                                                                          2025-11-12_1000000__1.txt: Removed 0 non-markovian points, 145 points of burn-in, keep 2215 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 1.975378 	for  H0
#            0.168698 	for  omega_b
#            0.418108 	for  omega_cdm
#            0.061786 	for  ln10^{10}A_s
#            0.408801 	for  n_s
#            0.030756 	for  tau_reio
#            0.032611 	for  fraction_maxion_ac__1
#            1.087150 	for  fraction_maxion_ac__2
#            0.101349 	for  fraction_maxion_ac__3
#            0.040442 	for  fraction_maxion_ac__4
#            0.001427 	for  A_planck
#            2.254784 	for  M
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_ax_planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/4_ax_planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12/2025-11-12_1000000__4.txt: Removed 0 non-markovian points, 2285 points of burn-in, keep 415 steps
#                                                                                                                                                2025-11-12_1000000__2.txt: Removed 0 non-markovian points, 1367 points of burn-in, keep 913 steps
#                                                                                                                                                2025-11-12_1000000__3.txt: Removed everything: chain not converged
#                                                                                                                                                2025-11-12_1000000__1.txt: Removed everything: chain not converged
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.715603 	for  H0
#            0.040158 	for  omega_b
#            0.000372 	for  omega_cdm
#            0.002059 	for  ln10^{10}A_s
#            0.061431 	for  n_s
#            0.004138 	for  tau_reio
#            0.010533 	for  fraction_maxion_ac__1
#            0.330462 	for  fraction_maxion_ac__2
#            0.202282 	for  fraction_maxion_ac__3
#            0.048082 	for  fraction_maxion_ac__4
#            0.000956 	for  A_planck
#            0.902038 	for  M
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_ax_planck_TTTEEElensing_pantheon_plus_desi2025-11-12
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_ax_planck_TTTEEElensing_pantheon_plus_desi2025-11-12/2025-11-12_10000__2.txt  : Removed 0 non-markovian points, 208 points of burn-in, keep 590 steps
#                                                                                                                                               2025-11-12_10000__3.txt  : Removed 0 non-markovian points, 142 points of burn-in, keep 656 steps
#                                                                                                                                               2025-11-12_10000__1.txt  : Removed 0 non-markovian points, 252 points of burn-in, keep 455 steps
#                                                                                                                                               2025-11-12_10000__4.txt  : Removed 0 non-markovian points, 313 points of burn-in, keep 181 steps
#                                                                                                                                               2025-11-18_1010000__1.txt: Removed 0 non-markovian points, 252 points of burn-in, keep 700 steps
#                                                                                                                                               2025-11-18_1010000__2.txt: Removed 0 non-markovian points, 142 points of burn-in, keep 941 steps
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.630979 	for  H0
#            0.324570 	for  omega_b
#            0.329647 	for  omega_cdm
#            0.075077 	for  ln10^{10}A_s
#            0.336444 	for  n_s
#            0.091857 	for  tau_reio
#            0.050570 	for  fraction_maxion_ac__1
#            0.039060 	for  fraction_maxion_ac__2
#            0.144854 	for  fraction_maxion_ac__3
#            0.200737 	for  fraction_maxion_ac__4
#            0.156830 	for  fraction_maxion_ac__5
#            0.494026 	for  fraction_maxion_ac__6
#            0.153384 	for  fraction_maxion_ac__7
#            0.066017 	for  fraction_maxion_ac__8
#            0.054879 	for  fraction_maxion_ac__9
#            0.027668 	for  A_planck
#            0.540047 	for  M
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  M
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_ax_planck_TTTEEElensing_pantheon_plus_sh0es_desi2025-11-12
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/9_ax_planck_TTTEEElensing_pantheon_plus_sh0es_desi2025-11-12/2025-11-12_1000000__4.txt: Removed 0 non-markovian points, 697 points of burn-in, keep 778 steps
#                                                                                                                                                     2025-11-12_1000000__2.txt: Removed 0 non-markovian points, 1372 points of burn-in, keep 123 steps
#                                                                                                                                                     2025-11-12_1000000__3.txt: Removed 0 non-markovian points, 682 points of burn-in, keep 713 steps
#                                                                                                                                                     2025-11-12_1000000__1.txt: Removed everything: chain not converged
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.096482 	for  H0
#            0.049855 	for  omega_b
#            0.165671 	for  omega_cdm
#            0.032833 	for  ln10^{10}A_s
#            0.101299 	for  n_s
#            0.034851 	for  tau_reio
#            0.004486 	for  fraction_maxion_ac__1
#            0.009487 	for  fraction_maxion_ac__2
#            0.047059 	for  fraction_maxion_ac__3
#            0.383033 	for  fraction_maxion_ac__4
#            0.093652 	for  fraction_maxion_ac__5
#            0.267689 	for  fraction_maxion_ac__6
#            0.027047 	for  fraction_maxion_ac__7
#            0.221036 	for  fraction_maxion_ac__8
#            0.339679 	for  fraction_maxion_ac__9
#            0.007200 	for  A_planck
#            0.186411 	for  M
# -----------------------------------------------
#  -> Computing histograms for  H0
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12/2025-11-12_1000000__8.txt: Removed everything: chain not converged
#                                                                                                                                           2025-11-12_1000000__4.txt: Removed everything: chain not converged
#                                                                                                                                           2025-11-12_1000000__5.txt: Removed 0 non-markovian points, 877 points of burn-in, keep 568 steps
#                                                                                                                                           2025-11-12_1000000__7.txt: Removed everything: chain not converged
#                                                                                                                                           2025-11-12_1000000__6.txt: Removed 0 non-markovian points, 1330 points of burn-in, keep 35 steps
#                                                                                                                                           2025-11-12_1000000__2.txt: Removed everything: chain not converged
#                                                                                                                                           2025-11-12_1000000__3.txt: Removed everything: chain not converged
#                                                                                                                                           2025-11-12_1000000__1.txt: Removed everything: chain not converged
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 0.000001 	for  H0
#            0.007637 	for  omega_b
#            0.082760 	for  omega_cdm
#            0.005453 	for  ln10^{10}A_s
#            0.005907 	for  n_s
#            0.013061 	for  tau_reio
#            0.020995 	for  fraction_maxion_ac__1
#            0.132026 	for  fraction_maxion_ac__2
#            0.012241 	for  fraction_maxion_ac__3
#            1.670125 	for  fraction_maxion_ac__4
#            0.155242 	for  fraction_maxion_ac__5
#            0.148770 	for  fraction_maxion_ac__6
#            0.109560 	for  fraction_maxion_ac__7
#            0.138121 	for  fraction_maxion_ac__8
#            1.045894 	for  fraction_maxion_ac__9
#            0.015600 	for  A_planck
#            0.002062 	for  M
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files
# Running: python /Users/bellamarco01/uni/1_master_thesis/montepython/montepython_public/montepython/MontePython.py info /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/planck_TTTEEElensing_pantheon_plus2025-11-12
#  /!\ PyMultiNest detected but MultiNest likely not installed correctly. You can
#      safely ignore this if not running with option -m NS
# Running Monte Python v3.6.1
#
# --> Scanning file /Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp/planck_TTTEEElensing_pantheon_plus2025-11-12/2025-11-12_1000000__8.txt: Removed 0 non-markovian points, 1199 points of burn-in, keep 811 steps
#                                                                                                                                     2025-11-12_1000000__4.txt: Removed everything: chain not converged
#                                                                                                                                     2025-11-12_1000000__5.txt: Removed 0 non-markovian points, 363 points of burn-in, keep 877 steps
#                                                                                                                                     2025-11-12_1000000__7.txt: Removed 0 non-markovian points, 576 points of burn-in, keep 794 steps
#                                                                                                                                     2025-11-12_1000000__6.txt: Removed 0 non-markovian points, 291 points of burn-in, keep 1049 steps
#                                                                                                                                     2025-11-12_1000000__3.txt: Removed everything: chain not converged
#                                                                                                                                     2025-11-12_1000000__1.txt: Removed everything: chain not converged
# --> Computing mean values
# --> Computing variance
# --> Computing convergence criterium (Gelman-Rubin)
#  -> R-1 is 1.357370 	for  H0
#            0.968767 	for  omega_b
#            0.980921 	for  omega_cdm
#            0.181597 	for  ln10^{10}A_s
#            0.353899 	for  n_s
#            0.239801 	for  tau_reio
#            0.018945 	for  fraction_maxion_ac__1
#            0.028041 	for  fraction_maxion_ac__2
#            0.149001 	for  fraction_maxion_ac__3
#            0.301607 	for  fraction_maxion_ac__4
#            0.140107 	for  fraction_maxion_ac__5
#            0.303555 	for  fraction_maxion_ac__6
#            0.176413 	for  fraction_maxion_ac__7
#            0.133549 	for  fraction_maxion_ac__8
#            0.069626 	for  fraction_maxion_ac__9
#            0.060760 	for  A_planck
#            1.533501 	for  M
# -----------------------------------------------
#  -> Computing histograms for  H0
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_b
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  omega_cdm
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  ln10^{10}A_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  n_s
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  tau_reio
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__1
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__2
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__3
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__4
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__5
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__6
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__7
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__8
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  fraction_maxion_ac__9
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  A_planck
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
#  -> Computing histograms for  M
#  /!\ Polyfit may be poorly conditioned
#  /!\ could not derive minimum credible intervals for this multimodal posterior
#  /!\ please try running longer chains or reducing the number of bins with --bins
#      BINS (default: 20)
# -----------------------------------------------
# --> Saving figures to .pdf files
# --> Writing .info and .tex files

# %%
import fitz  # PyMuPDF
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

base = Path("/Users/bellamarco01/uni/1_master_thesis/montepython_chains/chains_mp")

chains = [
         "4_ax_planck_TTTEEElensing_pantheon_plus2025-11-12",
         "4_ax_planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12",
         "9_ax_planck_TTTEEElensing_pantheon_plus_desi2025-11-12",
         "9_ax_planck_TTTEEElensing_pantheon_plus_sh0es_desi2025-11-12",
         "planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12",
         "planck_TTTEEElensing_pantheon_plus2025-11-12",
         ]
for chain_name in chains:
    chain_dir = base / chain_name / "plots"
    pdfs = list(chain_dir.glob("*.pdf"))

    if not pdfs:
        print(f"No PDFs found in {chain_dir}")
        continue

    for pdf_path in pdfs:
        print(f"Displaying {pdf_path.name}")
        doc = fitz.open(pdf_path)
        for page_num in range(len(doc)):
            page = doc.load_page(page_num)
            pix = page.get_pixmap()  # Render page to pixmap
            img = np.frombuffer(pix.samples, dtype=np.uint8).reshape(pix.height, pix.width, pix.n)  # Convert to array

            plt.figure(figsize=(12, 8))
            plt.imshow(img)
            plt.axis('off')
            plt.show()
# Out:
# Displaying 4_ax_planck_TTTEEElensing_pantheon_plus2025-11-12_triangle.pdf
# Displaying 4_ax_planck_TTTEEElensing_pantheon_plus2025-11-12_1d.pdf
# Displaying 4_ax_planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12_1d.pdf
# Displaying 4_ax_planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12_triangle.pdf
# Displaying 9_ax_planck_TTTEEElensing_pantheon_plus_desi2025-11-12_1d.pdf
# Displaying 9_ax_planck_TTTEEElensing_pantheon_plus_desi2025-11-12_triangle.pdf
# Displaying 9_ax_planck_TTTEEElensing_pantheon_plus_sh0es_desi2025-11-12_triangle.pdf
# Displaying 9_ax_planck_TTTEEElensing_pantheon_plus_sh0es_desi2025-11-12_1d.pdf
# Displaying planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12_1d.pdf
# Displaying planck_TTTEEElensing_pantheon_plus_sh0es2025-11-12_triangle.pdf
# Displaying planck_TTTEEElensing_pantheon_plus2025-11-12_triangle.pdf
# Displaying planck_TTTEEElensing_pantheon_plus2025-11-12_1d.pdf
